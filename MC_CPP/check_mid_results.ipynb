# %%
import matplotlib.pyplot as plt
import random
import numpy as np
import pandas as pd

from pathlib import Path

# %% [markdown]
# Гомополимер из H
#
#
# $\epsilon = -1$
#
# Начальное состояние - три мономера
#
# fugacity = -0.55

# %%
results = np.loadtxt("something.txt")

# %%
mean_e = results[:,0]
mean_c = results[:,1]
mean_n = results[:,2]

ts = np.arange(0.15, 3.67, 0.02)

# %%
plt.figure(figsize=(10, 6))
plt.title("Средняя энергия")
plt.plot( ts, mean_e , ".")
plt.xlabel("T", fontsize = 14)
plt.ylabel(" <E>  ", fontsize=14)
# Out:
# Text(0, 0.5, ' <E>  ')

# %%
plt.figure(figsize=(10, 6))
plt.title("Теплоемкость")
plt.plot( ts, mean_c , ".")
plt.xlabel("T", fontsize = 14)
plt.ylabel("C ", fontsize=14)
# Out:
# Text(0, 0.5, 'C ')

# %%
plt.figure(figsize=(10, 6))
plt.title("Средняя длина")
plt.plot( ts, mean_n , ".")
plt.xlabel("T", fontsize = 14)
plt.ylabel("<N> ", fontsize=14)
# Out:
# Text(0, 0.5, '<N> ')

# %% [markdown]
# Начальное состояние - три мономера
#
# fugacity = -0.65

# %%
results = np.loadtxt("something.txt")

mean_e = results[:,0]
mean_c = results[:,1]
mean_n = results[:,2]

ts = np.arange(0.15, 3.67, 0.02)




plt.figure(figsize=(10, 6))
plt.title("Средняя энергия")
plt.plot( ts, mean_e , ".")
plt.xlabel("T", fontsize = 14)
plt.ylabel(" <E>  ", fontsize=14)
# Out:
# Text(0, 0.5, ' <E>  ')

# %%
plt.figure(figsize=(10, 6))
plt.title("Средняя длина")
plt.plot( ts, mean_n , ".")
plt.xlabel("T", fontsize = 14)
plt.ylabel("<N> ", fontsize=14)
# Out:
# Text(0, 0.5, '<N> ')

# %%
fugacity = -0.85

results = np.loadtxt("something.txt")

mean_e = results[:,0]
mean_c = results[:,1]
mean_n = results[:,2]

ts = np.arange(0.15, 3.67, 0.02)




plt.figure(figsize=(10, 6))
plt.title("Средняя энергия")
plt.plot( ts, mean_e , ".")
plt.xlabel("T", fontsize = 14)
plt.ylabel(" <E>  ", fontsize=14)
# Out:
# Text(0, 0.5, ' <E>  ')

# %%
plt.figure(figsize=(10, 6))
plt.title("Средняя длина")
plt.plot( ts, mean_n , ".")
plt.xlabel("T", fontsize = 14)
plt.ylabel("<N> ", fontsize=14)
# Out:
# Text(0, 0.5, '<N> ')
