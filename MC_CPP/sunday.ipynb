# %%
import matplotlib.pyplot as plt
import random
import numpy as np
import pandas as pd

from pathlib import Path

# %% [markdown]
# $$ \beta = \exp(\frac{f}{T})$$

# %% [markdown]
# Для гомополимера:

# %%
results = np.loadtxt("something.txt")

mean_e = results[:,0]
mean_c = results[:,1]
mean_n = results[:,2]


ts = np.arange(-6.2,  3.4+0.1, 0.1 )


plt.figure(figsize=(10, 6))
plt.title("Средняя длина")
plt.plot( ts, mean_n , ".")
plt.xlabel("f", fontsize = 14)
plt.ylabel("<N> ", fontsize=14)
plt.ylim(0,100)
# Out:
# (0, 100)

# %%
plt.figure(figsize=(10, 6))
plt.title("Средняя длина")
plt.plot( ts, mean_n , ".")
plt.xlabel("f", fontsize = 14)
plt.ylabel("<N> ", fontsize=14)
plt.xlim(1.0,2.1)
plt.ylim(0,50)
# Out:
# (0, 50)

# %% [markdown]
# Для блуждания:

# %%
results = np.loadtxt("something.txt")

mean_e = results[:,0]
mean_c = results[:,1]
mean_n = results[:,2]


ts = np.arange(1.0,  2.01, 0.01 )


plt.figure(figsize=(10, 6))
plt.title("Средняя длина")
plt.plot( ts, mean_n , ".")
plt.xlabel("f", fontsize = 14)
plt.ylabel("<N> ", fontsize=14)
plt.ylim(0,50)
# Out:
# (0, 50)

# %% [markdown]
# Для гомополимера:

# %%
results = np.loadtxt("something.txt")

mean_e = results[:,0]
mean_c = results[:,1]
mean_n = results[:,2]


ts = np.arange(1.0,  2.01, 0.01 )


plt.figure(figsize=(10, 6))
plt.title("Средняя длина")
plt.plot( ts, mean_n , ".")
plt.xlabel("f", fontsize = 14)
plt.ylabel("<N> ", fontsize=14)
plt.ylim(0,100)
# Out:
# (0, 100)
